# %%
import torch

if torch.cuda.is_available():
    num_gpus = torch.cuda.device_count()
    print(f"Number of GPUs: {num_gpus}")

    for i in range(num_gpus):
        print(f"GPU {i}: {torch.cuda.get_device_name(i)}")
        print(f"  CUDA Capability: {torch.cuda.get_device_capability(i)}")
else:
    print("No GPU available. Please check your CUDA installation.")
# Out:
# Number of GPUs: 8
# GPU 0: NVIDIA A100-PCIE-40GB
#   CUDA Capability: (8, 0)
# GPU 1: NVIDIA A100-PCIE-40GB
#   CUDA Capability: (8, 0)
# GPU 2: NVIDIA A100-PCIE-40GB
#   CUDA Capability: (8, 0)
# GPU 3: NVIDIA A100-PCIE-40GB
#   CUDA Capability: (8, 0)
# GPU 4: NVIDIA A100-PCIE-40GB
#   CUDA Capability: (8, 0)
# GPU 5: NVIDIA A100-PCIE-40GB
#   CUDA Capability: (8, 0)
# GPU 6: NVIDIA A100-PCIE-40GB
#   CUDA Capability: (8, 0)
# GPU 7: NVIDIA A100-PCIE-40GB
#   CUDA Capability: (8, 0)

# %%
# %cd ../no_git_oic/minimind
# !pwd
# Out:
# /mnt/data/llch/for_llm_upgrade/no_git_oic/minimind
# /mnt/data/llch/for_llm_upgrade/no_git_oic/minimind

# %%
# 去命令行执行,界面执行很卡
# modelscope download --dataset gongjy/minimind_dataset --local_dir ./dataset
# Out:
# Downloading Dataset to directory: /mnt/data/llch/for_llm_upgrade/0_预训练/dataset
# Processing 15 items:   0%|                          | 0.00/15.0 [00:00<?, ?it/s]
# Downloading [.gitattributes]:   0%|                 | 0.00/3.73k [00:00<?, ?B/s]
#
# Downloading [images/1.png]:   0%|                    | 0.00/9.00 [00:00<?, ?B/s]
#
#
# Downloading [images/dataset.jpg]:   0%|              | 0.00/146k [00:00<?, ?B/s]
#
#
#
# Downloading [dataset_infos.json]:   0%|               | 0.00/165 [00:00<?, ?B/s]
#
#
#
#
# Downloading [dpo.jsonl]:   0%|                       | 0.00/867M [00:00<?, ?B/s]
#
#
#
#
#
# Downloading [images/logo.png]:   0%|                 | 0.00/495k [00:00<?, ?B/s]
#
#
#
#
#
#
# Downloading [lora_identity.jsonl]:   0%|            | 0.00/22.3k [00:00<?, ?B/s]
#
#
#
#
#
#
#
# Downloading [lora_medical.jsonl]:   0%|             | 0.00/32.4M [00:00<?, ?B/s]
#
# Downloading [images/1.png]: 100%|█████████████| 9.00/9.00 [00:00<00:00, 19.8B/s]
# Processing 15 items:   7%|█▎                 | 1.00/15.0 [00:00<00:06, 2.18it/s]
#
# Downloading [pretrain_hq.jsonl]:   0%|              | 0.00/1.51G [00:00<?, ?B/s]
#
#
#
#
#
# Downloading [images/logo.png]:   1%|        | 3.37k/495k [00:00<01:08, 7.36kB/s]
#
#
#
# Downloading [dataset_infos.json]: 100%|██████████| 165/165 [00:00<00:00, 339B/s]
#
#
#
#
# Downloading [r1_mix_1024.jsonl]:   0%|               | 0.00/351M [00:00<?, ?B/s]
# Downloading [.gitattributes]: 100%|████████| 3.73k/3.73k [00:00<00:00, 7.75kB/s]
#
# Downloading [README.md]:   0%|                      | 0.00/10.9k [00:00<?, ?B/s]
#
#
# Downloading [images/dataset.jpg]:   2%|     | 3.46k/146k [00:00<00:20, 7.13kB/s]
#
#
#
#
#
#
# Downloading [lora_identity.jsonl]:  15%|▍  | 3.45k/22.3k [00:00<00:02, 6.96kB/s]
#
#
#
#
# Downloading [lora_identity.jsonl]: 100%|███| 22.3k/22.3k [00:00<00:00, 41.4kB/s]
#
#
#
#
#
#
#
# Processing 15 items:  27%|█████              | 4.00/15.0 [00:00<00:01, 8.73it/s]
#
#
#
#
#
#
#
# Downloading [lora_medical.jsonl]:   0%|  | 3.45k/32.4M [00:00<1:32:28, 6.13kB/s]
#
#
#
#
#
# Downloading [images/logo.png]:  16%|█▍       | 79.4k/495k [00:00<00:02, 171kB/s]
#
#
# Downloading [images/dataset.jpg]: 100%|███████| 146k/146k [00:00<00:00, 236kB/s]
#
#
#
# Downloading [sft_2048.jsonl]:   0%|                 | 0.00/8.33G [00:00<?, ?B/s]
#
#
#
#
# Downloading [images/logo.png]: 100%|██████████| 495k/495k [00:00<00:00, 720kB/s]
#
#
#
#
#
#
# Processing 15 items:  40%|███████▌           | 6.00/15.0 [00:00<00:00, 10.2it/s]
#
#
#
#
#
#
#
# Downloading [lora_medical.jsonl]
B/s]
#
#
# Downloading [sft_2048.jsonl]:   0%|      | 4.44M/8.33G [00:06<1:43:46, 1.44MB/s]
#
#
#
#
#
# Downloading [sft_512.jsonl]:   0%|       | 2.61M/7.01G [00:05<1:46:56, 1.17MB/s]
# Downloading [sft_mini_512.jsonl]:   1%|    | 8.74M/1.15G [00:05<06:44, 3.02MB/s]
#
#
#
#
#
#
# Downloading [sft_1024.jsonl]:   0%|        | 6.20M/5.21G [00:06<53:32, 1.74MB/s]
#
# Downloading [pretrain_hq.jsonl]:   1%|     | 19.9M/1.51G [00:06<11:12, 2.37MB/s]
#
#
#
# Downloading [r1_mix_1024.jsonl]:   3%|▏     | 9.00M/351M [00:06<03:16, 1.82MB/s]
#
#
#
#
# Downloading [dpo.jsonl]:   2%|▎             | 17.8M/867M [00:06<08:15, 1.80MB/s]
#
#
# Downloading [sft_2048.jsonl]:   0%|      | 4.60M/8.33G [00:06<1:46:59, 1.39MB/s]
#
#
#
#
#
# Downloading [sft_512.jsonl]:   0%|       | 2.74M/7.01G [00:06<1:47:04, 1.17MB/s]
# Downloading [sft_mini_512.jsonl]:   1%|    | 9.05M/1.15G [00:05<06:46, 3.01MB/s]
#
# Downloading [pretrain_hq.jsonl]:   1%|     | 20.1M/1.51G [00:06<11:15, 2.36MB/s]
#
#
#
#
#
#
# Downloading [sft_1024.jsonl]:   0%|        | 6.42M/5.21G [00:06<53:33, 1.74MB/s]
#
#
#
# Downloading [r1_mix_1024.jsonl]:   3%|▏     | 9.22M/351M [00:06<03:04, 1.94MB/s]
#
#
# Downloading [sft_2048.jsonl]:   0%|      | 4.82M/8.33G [00:06<1:40:52, 1.48MB/s]
# Downloading [sft_mini_512.jsonl]:   1%|    | 9.42M/1.15G [00:05<06:28, 3.15MB/s]
#
#
#
#
#
# Downloading [sft_512.jsonl]:   0%|       | 2.92M/7.01G [00:06<1:40:16, 1.25MB/s]
#
# Downloading [pretrain_hq.jsonl]:   1%|     | 20.4M/1.51G [00:06<11:03, 2.41MB/s]^C
# Processing 15 items:  53%|██████████▏        | 8.00/15.0 [00:06<00:06, 1.15it/s]
# Traceback (most recent call last):
#   File "/mnt/data/llch/for_llm_upgrade/.venv/lib/python3.12/site-packages/modelscope/utils/thread_utils.py", line 64, in wrapper
#     for future in as_completed(futures):
#                   ^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/lib/python3.12/concurrent/futures/_base.py", line 243, in as_completed
#     waiter.event.wait(wait_timeout)
#   File "/root/miniconda3/lib/python3.12/threading.py", line 655, in wait
#     signaled = self._cond.wait(timeout)
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/lib/python3.12/threading.py", line 355, in wait
#
#
#
#
# Downloading [r1_mix_1024.jsonl]:   3%|▏     | 9.44M/351M [00:06<03:09, 1.89MB/s]    waiter.acquire()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/mnt/data/llch/for_llm_upgrade/.venv/bin/modelscope", line 10, in <module>
#
#
#
#
#
#
#
# Downloading [sft_1024.jsonl]:   0%|        | 6.67M/5.21G [00:06<51:30, 1.81MB/s]    sys.exit(run_cmd())
#              ^^^^^^^^^
#   File "/mnt/data/llch/for_llm_upgrade/.venv/lib/python3.12/site-packages/modelscope/cli/cli.py", line 47, in run_cmd
#     cmd.execute()
#   File "/mnt/data/llch/for_llm_upgrade/.venv/lib/python3.12/site-packages/modelscope/cli/download.py", line 169, in execute
#     dataset_snapshot_download(
#   File "/mnt/data/llch/for_llm_upgrade/.venv/lib/python3.12/site-packages/modelscope/hub/snapshot_download.py", line 184, in dataset_snapshot_download
#     return _snapshot_download(
#            ^^^^^^^^^^^^^^^^^^^
#   File "/mnt/data/llch/for_llm_upgrade/.venv/lib/python3.12/site-packages/modelscope/hub/snapshot_download.py", line 334, in _snapshot_download
#     _download_file_lists(
#   File "/mnt/data/llch/for_llm_upgrade/.venv/lib/python3.12/site-packages/modelscope/hub/snapshot_download.py", line 520, in _download_file_lists
#     _download_single_file(filtered_repo_files)
#   File "/mnt/data/llch/for_llm_upgrade/.venv/lib/python3.12/site-packages/modelscope/utils/thread_utils.py", line 56, in wrapper
#     with ThreadPoolExecutor(max_workers=max_workers) as executor:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/lib/python3.12/concurrent/futures/_base.py", line 647, in __exit__
#     self.shutdown(wait=True)
#   File "/root/miniconda3/lib/python3.12/concurrent/futures/thread.py", line 239, in shutdown
#     t.join()
#   File "/root/miniconda3/lib/python3.12/threading.py", line 1149, in join
#     self._wait_for_tstate_lock()
#   File "/root/miniconda3/lib/python3.12/threading.py", line 1169, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#
#
#
#
#
# Downloading [dpo.jsonl]:   2%|▎             | 18.2M/867M [00:06<08:00, 1.85MB/s]
# Downloading [sft_mini_512.jsonl]:   1%|    | 9.74M/1.15G [00:05<06:35, 3.09MB/s]
#
# Downloading [pretrain_hq.jsonl]:   1%|     | 20.6M/1.51G [00:06<10:37, 2.50MB/s]
#
#
# Downloading [sft_2048.jsonl]:   0%|      | 5.04M/8.33G [00:06<1:36:48, 1.54MB/s]
#
#
#
#
#
# Downloading [sft_512.jsonl]:   0%|       | 3.11M/7.01G [00:06<1:36:09, 1.30MB/s]
#
#
#
#
# Downloading [dpo.jsonl]:   2%|▎             | 18.4M/867M [00:07<07:53, 1.88MB/s]
#
#
#
#
#
#
# Downloading [sft_1024.jsonl]:   0%|        | 6.92M/5.21G [00:06<49:55, 1.86MB/s]
#
#
#
# Downloading [r1_mix_1024.jsonl]:   3%|▏     | 9.69M/351M [00:06<03:08, 1.89MB/s]
#
# Downloading [pretrain_hq.jsonl]:   1%|     | 20.9M/1.51G [00:06<10:35, 2.51MB/s]
# Downloading [sft_mini_512.jsonl]:   1%|    | 10.1M/1.15G [00:05<06:19, 3.22MB/s]

# %%
# Step 1: 导入必要库
import os
import math
import warnings
import torch
from torch import optim, nn
import torch.distributed as dist
from torch.utils.tensorboard import SummaryWriter  # 新增TensorBoard
from torch.utils.data import DataLoader, DistributedSampler
from transformers import AutoTokenizer
from model.model import MiniMindLM
from model.LMConfig import LMConfig
from model.dataset import PretrainDataset

warnings.filterwarnings('ignore')

# %%
# Step 2: 配置参数解析
class Args:
    def __init__(self):
        self.out_dir = "out"
        self.epochs = 3
        self.batch_size = 32
        self.learning_rate = 5e-4
        self.device = "cuda" if torch.cuda.is_available() else "cpu" # 是否 cuda:0 
        self.dtype = "bfloat16"
        self.num_workers = 16
        self.accumulation_steps = 4
        self.grad_clip = 1.0  # 梯度裁剪（Gradient Clipping）的阈值
        self.log_interval = 50
        self.save_interval = 100
        self.dim = 512
        self.n_layers = 8
        self.max_seq_len = 512
        self.use_moe = False
        self.data_path = "./dataset/pretrain_hq.jsonl"
        self.ddp = False  # 设置为True时需要配合torchrun使用
        self.local_rank = -1

args = Args()
args.dim
# Out:
# 512

# %%
# Step 3: 初始化TensorBoard
writer = SummaryWriter(log_dir=os.path.join(args.out_dir, 'tensorboard'))

# %%
# Step 4: 分布式训练初始化
def init_distributed():
    # 如果 args.ddp 为 False，直接返回，不执行分布式初始化
    if not args.ddp:
        return
    # 初始化分布式进程组 使用 NCCL 后端，适合 GPU 集群的分布式训练
    dist.init_process_group(backend="nccl")
    args.local_rank = int(os.environ["LOCAL_RANK"])
    args.device = torch.device(f"cuda:{args.local_rank}")
    torch.cuda.set_device(args.device)
args.local_rank, args.device
# Out:
# (-1, 'cuda')

# %%
# Step 5: 模型和分词器初始化
def init_model():
    lm_config = LMConfig(
        dim=args.dim,
        n_layers=args.n_layers,
        max_seq_len=args.max_seq_len,
        use_moe=args.use_moe
    )
    
    tokenizer = AutoTokenizer.from_pretrained('./model/minimind_tokenizer')
    model = MiniMindLM(lm_config).to(args.device)
    
    if args.ddp:
        model = torch.nn.parallel.DistributedDataParallel(
            model,
            device_ids=[args.local_rank],
            output_device=args.local_rank
        )
    
    return model, tokenizer

# %%
def prepare_dataloader(tokenizer):
    dataset = PretrainDataset(
        args.data_path,
        tokenizer,
        max_length=args.max_seq_len
    )
    
    sampler = DistributedSampler(dataset) if args.ddp else None
    
    return DataLoader(
        dataset,
        batch_size=args.batch_size,
        shuffle=(sampler is None),
        sampler=sampler,
        num_workers=args.num_workers,
        pin_memory=True,
        drop_last=True
    )

# %%
# Step 7: 优化器和学习率调度器
def create_optimizer_and_scheduler(model):
    optimizer = torch.optim.AdamW(
        model.parameters(),
        lr=args.learning_rate,
        weight_decay=0.01
    )
    
    total_steps = len(train_loader) * args.epochs
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
        optimizer,
        T_max=total_steps
    )
    
    return optimizer, scheduler

# %%
# Step 8: 训练循环
def train(model, train_loader, optimizer, scheduler):
    model.train()
    loss_fct = nn.CrossEntropyLoss(reduction='none')
    scaler = torch.amp.GradScaler(enabled=args.dtype in ['float16', 'bfloat16'])
    
    for epoch in range(args.epochs):
        if args.ddp:
            train_loader.sampler.set_epoch(epoch)
            
        for step, (X, Y, loss_mask) in enumerate(train_loader):
            X, Y, loss_mask = X.to(args.device), Y.to(args.device), loss_mask.to(args.device)
            
            with torch.cuda.amp.autocast(dtype=args.dtype):
                outputs = model(X)
                loss = loss_fct(
                    outputs.logits.view(-1, outputs.logits.size(-1)),
                    Y.view(-1)
                )
                loss = (loss * loss_mask).sum() / loss_mask.sum()
                loss += outputs.aux_loss  # 添加辅助损失（如MoE损失）
                loss = loss / args.accumulation_steps
                
            scaler.scale(loss).backward()
            
            if (step + 1) % args.accumulation_steps == 0:
                scaler.unscale_(optimizer)
                torch.nn.utils.clip_grad_norm_(model.parameters(), args.grad_clip)
                scaler.step(optimizer)
                scaler.update()
                optimizer.zero_grad(set_to_none=True)
                
            scheduler.step()
            
            # 日志记录
            if step % args.log_interval == 0:
                current_lr = scheduler.get_last_lr()[0]
                writer.add_scalar('Loss/train', loss.item(), epoch * len(train_loader) + step)
                writer.add_scalar('Learning Rate', current_lr, epoch * len(train_loader) + step)
                
                print(f"Epoch {epoch+1}/{args.epochs} | Step {step}/{len(train_loader)} | "
                      f"Loss: {loss.item():.4f} | LR: {current_lr:.6f}")
                
            # 模型保存
            if step % args.save_interval == 0 and (not args.ddp or dist.get_rank() == 0):
                checkpoint = {
                    'model': model.module.state_dict() if args.ddp else model.state_dict(),
                    'optimizer': optimizer.state_dict(),
                    'epoch': epoch,
                    'step': step
                }
                torch.save(checkpoint, os.path.join(args.out_dir, f'checkpoint_{epoch}_{step}.pt'))

# %%
# 主执行流程
init_distributed()
model, tokenizer = init_model()
train_loader = prepare_dataloader(tokenizer)
optimizer, scheduler = create_optimizer_and_scheduler(model)
train(model, train_loader, optimizer, scheduler)
writer.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 6
#       4 train_loader = prepare_dataloader(tokenizer)
#       5 optimizer, scheduler = create_optimizer_and_scheduler(model)
# ----> 6 train(model, train_loader, optimizer, scheduler)
#       7 writer.close()
#
# Cell In[20], line 14, in train(model, train_loader, optimizer, scheduler)
#      11 for step, (X, Y, loss_mask) in enumerate(train_loader):
#      12     X, Y, loss_mask = X.to(args.device), Y.to(args.device), loss_mask.to(args.device)
# ---> 14     with torch.cuda.amp.autocast(dtype=args.dtype):
#      15         outputs = model(X)
#      16         loss = loss_fct(
#      17             outputs.logits.view(-1, outputs.logits.size(-1)),
#      18             Y.view(-1)
#      19         )
#
# File /mnt/data/llch/for_llm_upgrade/.venv/lib/python3.12/site-packages/torch/cuda/amp/autocast_mode.py:41, in autocast.__enter__(self)
#      39 if torch._jit_internal.is_scripting():
#      40     return self
# ---> 41 return super().__enter__()
#
# File /mnt/data/llch/for_llm_upgrade/.venv/lib/python3.12/site-packages/torch/amp/autocast_mode.py:362, in autocast.__enter__(self)
#     360 self.prev_fastdtype = torch.get_autocast_dtype(self.device)
#     361 torch.set_autocast_enabled(self.device, self._enabled)
# --> 362 torch.set_autocast_dtype(self.device, self.fast_dtype)  # type: ignore[arg-type]
#     363 torch.autocast_increment_nesting()
#     364 torch.set_autocast_cache_enabled(self._cache_enabled)
#
# TypeError: set_autocast_dtype(): argument 'dtype' (position 2) must be torch.dtype, not str
